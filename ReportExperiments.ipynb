# %%
# %pip install -r req_3_10_m1.txt
import argparse
import torch
# python train_single_step.py --save ./model-electricity-3.pt --data ./data/electricity.txt --num_nodes 321 --batch_size 4 --epochs 30 --horizon 3
import os
import easydict
from train_single_step import main
os.system("export PYTORCH_ENABLE_MPS_FALLBACK=1")

args = easydict.EasyDict({'data': './data/solar_AL.txt',
        'log_interval': 2000, 'save': 'model/model.pt',
        'optim': 'adam', 'L1Loss': True, 'normalize': 2,
        'device': 'mps', 'gcn_true': True, 'buildA_true': True,
        'gcn_depth': 2, 'num_nodes': 137, 'dropout': 0.3, 'subgraph_size': 20,
        'node_dim': 40, 'dilation_exponential': 2, 'conv_channels': 16,
        'residual_channels': 16, 'skip_channels': 32, 'end_channels': 64,
        'in_dim': 1, 'seq_in_len': 168, 'seq_out_len': 1, 'horizon': 3,
        'layers': 5, 'batch_size': 32, 'lr': 0.0001, 'weight_decay': 1e-05, 'clip': 5,
        'propalpha': 0.05, 'tanhalpha': 3, 'epochs': 1, 'num_split': 1, 'step_size': 100})

device = torch.device(args.device)
torch.set_num_threads(4)
main(args,torch,device)
# Out:
# env: PYTORCH_ENABLE_MPS_FALLBACK=1
# Requirement already satisfied: certifi==2022.9.24 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 1)) (2022.9.24)
# Requirement already satisfied: charset-normalizer==2.1.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 2)) (2.1.1)
# Requirement already satisfied: contourpy==1.0.6 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 3)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools==4.38.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 5)) (4.38.0)
# Requirement already satisfied: idna==3.4 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 6)) (3.4)
# Requirement already satisfied: joblib==1.2.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 7)) (1.2.0)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 8)) (1.4.4)
# Requirement already satisfied: matplotlib==3.6.2 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 9)) (3.6.2)
# Requirement already satisfied: numexpr==2.8.4 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 10)) (2.8.4)
# Requirement already satisfied: numpy==1.23.4 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 11)) (1.23.4)
# Requirement already satisfied: packaging==21.3 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 12)) (21.3)
# Requirement already satisfied: pandas==1.5.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 13)) (1.5.1)
# Requirement already satisfied: Pillow==9.3.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 14)) (9.3.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 15)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 16)) (2.8.2)
# Requirement already satisfied: pytz==2022.6 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 17)) (2022.6)
# Requirement already satisfied: requests==2.28.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 18)) (2.28.1)
# Requirement already satisfied: scikit-learn==1.1.3 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 19)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 20)) (1.9.3)
# Requirement already satisfied: six==1.16.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 21)) (1.16.0)
# Requirement already satisfied: tables==3.7.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 22)) (3.7.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 23)) (3.1.0)
# Requirement already satisfied: torch==1.12.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 24)) (1.12.1)
# Requirement already satisfied: torchaudio==0.12.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 25)) (0.12.1)
# Requirement already satisfied: torchvision==0.13.1 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 26)) (0.13.1)
# Requirement already satisfied: typing_extensions==4.4.0 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 27)) (4.4.0)
# Requirement already satisfied: urllib3==1.26.12 in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 28)) (1.26.12)
# Requirement already satisfied: jupyter in ./venv10/lib/python3.10/site-packages (from -r req_3_10_m1.txt (line 29)) (1.0.0)
# Requirement already satisfied: notebook in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (6.5.2)
# Requirement already satisfied: qtconsole in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (5.4.0)
# Requirement already satisfied: jupyter-console in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (6.4.4)
# Requirement already satisfied: nbconvert in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (7.2.5)
# Requirement already satisfied: ipywidgets in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (8.0.2)
# Requirement already satisfied: ipykernel in ./venv10/lib/python3.10/site-packages (from jupyter->-r req_3_10_m1.txt (line 29)) (6.17.1)
# Requirement already satisfied: ipython>=7.23.1 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (8.6.0)
# Requirement already satisfied: nest-asyncio in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (7.4.7)
# Requirement already satisfied: psutil in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (6.2)
# Requirement already satisfied: appnope in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.1.3)
# Requirement already satisfied: pyzmq>=17 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (24.0.1)
# Requirement already satisfied: traitlets>=5.1.0 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (5.5.0)
# Requirement already satisfied: debugpy>=1.0 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (1.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./venv10/lib/python3.10/site-packages (from ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.1.6)
# Requirement already satisfied: widgetsnbextension~=4.0 in ./venv10/lib/python3.10/site-packages (from ipywidgets->jupyter->-r req_3_10_m1.txt (line 29)) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in ./venv10/lib/python3.10/site-packages (from ipywidgets->jupyter->-r req_3_10_m1.txt (line 29)) (3.0.3)
# Requirement already satisfied: pygments in ./venv10/lib/python3.10/site-packages (from jupyter-console->jupyter->-r req_3_10_m1.txt (line 29)) (2.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./venv10/lib/python3.10/site-packages (from jupyter-console->jupyter->-r req_3_10_m1.txt (line 29)) (3.0.33)
# Requirement already satisfied: defusedxml in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (0.7.1)
# Requirement already satisfied: nbformat>=5.1 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (5.7.0)
# Requirement already satisfied: beautifulsoup4 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (4.11.1)
# Requirement already satisfied: markupsafe>=2.0 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (0.7.0)
# Requirement already satisfied: jupyterlab-pygments in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.2)
# Requirement already satisfied: tinycss2 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (1.5.0)
# Requirement already satisfied: jinja2>=3.0 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (3.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (2.0.4)
# Requirement already satisfied: bleach in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (5.0.1)
# Requirement already satisfied: jupyter-core>=4.7 in ./venv10/lib/python3.10/site-packages (from nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (5.0.0)
# Requirement already satisfied: argon2-cffi in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (1.8.0)
# Requirement already satisfied: prometheus-client in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.15.0)
# Requirement already satisfied: nbclassic>=0.4.7 in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.4.8)
# Requirement already satisfied: terminado>=0.8.3 in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.17.0)
# Requirement already satisfied: ipython-genutils in ./venv10/lib/python3.10/site-packages (from notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.0)
# Requirement already satisfied: qtpy>=2.0.1 in ./venv10/lib/python3.10/site-packages (from qtconsole->jupyter->-r req_3_10_m1.txt (line 29)) (2.3.0)
# Requirement already satisfied: jedi>=0.16 in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (4.8.0)
# Requirement already satisfied: decorator in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (5.1.1)
# Requirement already satisfied: stack-data in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.6.1)
# Requirement already satisfied: backcall in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.0)
# Requirement already satisfied: pickleshare in ./venv10/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.7.5)
# Requirement already satisfied: entrypoints in ./venv10/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.4)
# Requirement already satisfied: platformdirs in ./venv10/lib/python3.10/site-packages (from jupyter-core>=4.7->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (2.5.4)
# Requirement already satisfied: jupyter-server>=1.8 in ./venv10/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (1.23.3)
# Requirement already satisfied: notebook-shim>=0.1.0 in ./venv10/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.2)
# Requirement already satisfied: fastjsonschema in ./venv10/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in ./venv10/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (4.17.1)
# Requirement already satisfied: wcwidth in ./venv10/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.5)
# Requirement already satisfied: ptyprocess in ./venv10/lib/python3.10/site-packages (from terminado>=0.8.3->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./venv10/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./venv10/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (2.3.2.post1)
# Requirement already satisfied: webencodings in ./venv10/lib/python3.10/site-packages (from bleach->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./venv10/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv10/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in ./venv10/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r req_3_10_m1.txt (line 29)) (22.1.0)
# Requirement already satisfied: websocket-client in ./venv10/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in ./venv10/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in ./venv10/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (1.15.1)
# Requirement already satisfied: pure-eval in ./venv10/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./venv10/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv10/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r req_3_10_m1.txt (line 29)) (2.1.0)
# Requirement already satisfied: sniffio>=1.1 in ./venv10/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (1.3.0)
# Requirement already satisfied: pycparser in ./venv10/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r req_3_10_m1.txt (line 29)) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# {'data': './data/solar_AL.txt', 'log_interval': 2000, 'save': 'model/model.pt', 'optim': 'adam', 'L1Loss': True, 'normalize': 2, 'device': 'mps', 'gcn_true': True, 'buildA_true': True, 'gcn_depth': 2, 'num_nodes': 137, 'dropout': 0.3, 'subgraph_size': 20, 'node_dim': 40, 'dilation_exponential': 2, 'conv_channels': 16, 'residual_channels': 16, 'skip_channels': 32, 'end_channels': 64, 'in_dim': 1, 'seq_in_len': 168, 'seq_out_len': 1, 'horizon': 3, 'layers': 5, 'batch_size': 32, 'lr': 0.0001, 'weight_decay': 1e-05, 'clip': 5, 'propalpha': 0.05, 'tanhalpha': 3, 'epochs': 1, 'num_split': 1, 'step_size': 100}
# The recpetive field size is 187
# Number of model parameters is 347665
# begin training
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [4], line 26
#      24 device = torch.device(args.device)
#      25 torch.set_num_threads(4)
# ---> 26 main(args,torch,device)
#
# File ~/Git/MTGNN/train_single_step.py:173, in main(args, torch, device)
#     171 corr = []
#     172 for i in range(10):
# --> 173     val_acc, val_rae, val_corr, test_acc, test_rae, test_corr = batch_main(args, torch, device)
#     174     vacc.append(val_acc)
#     175     vrae.append(val_rae)
#
# File ~/Git/MTGNN/train_single_step.py:129, in batch_main(args, torch, device)
#     127 for epoch in range(1, args.epochs + 1):
#     128     epoch_start_time = time.time()
# --> 129     train_loss = train(Data, Data.train[0], Data.train[1], model, criterion, optim, args.batch_size, args,
#     130                        torch, device)
#     131     val_loss, val_rae, val_corr = evaluate(Data, Data.valid[0], Data.valid[1], model, evaluateL2, evaluateL1,
#     132                                            args.batch_size)
#     133     print(
#     134         '| end of epoch {:3d} | time: {:5.2f}s | train_loss {:5.4f} | valid rse {:5.4f} | valid rae {:5.4f} | valid corr  {:5.4f}'.format(
#     135             epoch, (time.time() - epoch_start_time), train_loss, val_loss, val_rae, val_corr), flush=True)
#
# File ~/Git/MTGNN/train_single_step.py:77, in train(data, X, Y, model, criterion, optim, batch_size, args, torch, device)
#      75     id = perm[j * num_sub:]
#      76 id = torch.tensor(id).to(device)
# ---> 77 tx = X[:, :, id, :]
#      78 ty = Y[:, id]
#      79 output = model(tx, id)
#
# NotImplementedError: The operator 'aten::index.Tensor' is not current implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
